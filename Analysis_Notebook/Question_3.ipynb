# %% [markdown]
# # Question #3 What's the probability that a patient who has COVID will be recovered vs passing away(death)?

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading Data file

# %%
# Death Sata Set

dfA_0=pd.read_csv("time_series_covid19_deaths_global_03-31-2020.csv")
dfA_0
# Out:
#                Province/State  Country/Region        Lat       Long  1/22/20  \
# 0                         NaN     Afghanistan  33.000000  65.000000        0
# 1                         NaN         Albania  41.153300  20.168300        0
# 2                         NaN         Algeria  28.033900   1.659600        0
# 3                         NaN         Andorra  42.506300   1.521800        0
# 4                         NaN          Angola -11.202700  17.873900        0
# ..                        ...             ...        ...        ...      ...
# 251  Turks and Caicos Islands  United Kingdom  21.694000 -71.797900        0
# 252                       NaN      MS Zaandam   0.000000   0.000000        0
# 253                       NaN        Botswana -22.328500  24.684900        0
# 254                       NaN         Burundi  -3.373100  29.918900        0
# 255                       NaN    Sierra Leone   8.460555 -11.779889        0
#
# ...

# %%
# Recovery Datasets

dfB_0=pd.read_csv("time_series_covid19_recovered_global_03-31-2020.csv")
dfB_0
# Out:
#                Province/State  Country/Region        Lat       Long  1/22/20  \
# 0                         NaN     Afghanistan  33.000000  65.000000        0
# 1                         NaN         Albania  41.153300  20.168300        0
# 2                         NaN         Algeria  28.033900   1.659600        0
# 3                         NaN         Andorra  42.506300   1.521800        0
# 4                         NaN          Angola -11.202700  17.873900        0
# ..                        ...             ...        ...        ...      ...
# 237  Turks and Caicos Islands  United Kingdom  21.694000 -71.797900        0
# 238                       NaN      MS Zaandam   0.000000   0.000000        0
# 239                       NaN        Botswana -22.328500  24.684900        0
# 240                       NaN         Burundi  -3.373100  29.918900        0
# 241                       NaN    Sierra Leone   8.460555 -11.779889        0
#
# ...

# %%
# Confirmed Case Datasets

dfC_0=pd.read_csv("time_series_covid19_confirmed_global_03-31-20.csv")
dfC_0
# Out:
#                Province/State  Country/Region        Lat       Long  1/22/20  \
# 0                         NaN     Afghanistan  33.000000  65.000000        0
# 1                         NaN         Albania  41.153300  20.168300        0
# 2                         NaN         Algeria  28.033900   1.659600        0
# 3                         NaN         Andorra  42.506300   1.521800        0
# 4                         NaN          Angola -11.202700  17.873900        0
# ..                        ...             ...        ...        ...      ...
# 251  Turks and Caicos Islands  United Kingdom  21.694000 -71.797900        0
# 252                       NaN      MS Zaandam   0.000000   0.000000        0
# 253                       NaN        Botswana -22.328500  24.684900        0
# 254                       NaN         Burundi  -3.373100  29.918900        0
# 255                       NaN    Sierra Leone   8.460555 -11.779889        0
#
# ...

# %%
dfC_0.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
#        '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
#        '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
#        '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20',
#        '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20'],
#       dtype='object')

# %% [markdown]
# ### Making a Dataframe of our required Dates and summing

# %%
# Death Data set
dfA_1=dfA_0[['Province/State', 'Country/Region', 'Lat', 'Long','2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
       '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
       '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
       '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
       '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
       '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
       '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
       '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
       '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20',
       '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20']]

dfA_2=dfA_1[:]
dfA_2['Sum_Death_feb_March']=dfA_1.iloc[:,5:].sum(axis=1)
dfA_2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                Province/State  Country/Region        Lat       Long  2/1/20  \
# 0                         NaN     Afghanistan  33.000000  65.000000       0
# 1                         NaN         Albania  41.153300  20.168300       0
# 2                         NaN         Algeria  28.033900   1.659600       0
# 3                         NaN         Andorra  42.506300   1.521800       0
# 4                         NaN          Angola -11.202700  17.873900       0
# ..                        ...             ...        ...        ...     ...
# 251  Turks and Caicos Islands  United Kingdom  21.694000 -71.797900       0
# ...

# %%
# Recovery Datasets

dfB_1=dfB_0[['Province/State', 'Country/Region', 'Lat', 'Long', 
             '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
       '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
       '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
       '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
       '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
       '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
       '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
       '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
       '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20',
       '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20']]

dfB_2=dfB_1[:]
dfB_2['Sum_Recovered_feb_March']=dfB_1.iloc[:,5:].sum(axis=1)
dfB_2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#                Province/State  Country/Region        Lat       Long  2/1/20  \
# 0                         NaN     Afghanistan  33.000000  65.000000       0
# 1                         NaN         Albania  41.153300  20.168300       0
# 2                         NaN         Algeria  28.033900   1.659600       0
# 3                         NaN         Andorra  42.506300   1.521800       0
# 4                         NaN          Angola -11.202700  17.873900       0
# ..                        ...             ...        ...        ...     ...
# ...

# %%
# Confirmed Cases Datasets

dfC_1=dfC_0[['Province/State', 'Country/Region', 'Lat', 'Long', 
             '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
       '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
       '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
       '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
       '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
       '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
       '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
       '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
       '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20',
       '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20']]

dfC_2=dfC_1[:]
dfC_2['Sum_Confirmed_feb_March']=dfC_1.iloc[:,5:].sum(axis=1)
dfC_2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#                Province/State  Country/Region        Lat       Long  2/1/20  \
# 0                         NaN     Afghanistan  33.000000  65.000000       0
# 1                         NaN         Albania  41.153300  20.168300       0
# 2                         NaN         Algeria  28.033900   1.659600       0
# 3                         NaN         Andorra  42.506300   1.521800       0
# 4                         NaN          Angola -11.202700  17.873900       0
# ..                        ...             ...        ...        ...     ...
# ...

# %% [markdown]
# ### Total Confirmed Cases Datasets

# %%
Total_COVID_19_confirmed=dfC_2['Sum_Confirmed_feb_March'].sum(axis=0)
Total_COVID_19_confirmed
# Out:
# 10553803

# %% [markdown]
# ### Total Recovered Cases Datasets

# %%
Total_COVID_19_Recoverd=dfB_2['Sum_Recovered_feb_March'].sum(axis=0)
Total_COVID_19_Recoverd
# Out:
# 3086599

# %% [markdown]
# ### Total Death Cases Datasets

# %%
Total_COVID_19_Death=dfA_2['Sum_Death_feb_March'].sum(axis=0)
Total_COVID_19_Death
# Out:
# 432849

# %% [markdown]
# ## Probability that a patient who has COVID will be recovered - P(recover)

# %%
P_recover=Total_COVID_19_Recoverd/(Total_COVID_19_confirmed)
P_recover
# Out:
# 0.2924632002321817

# %% [markdown]
# ## Probability that a patient who has COVID will Die - P(death)

# %%
P_death=Total_COVID_19_Death/(Total_COVID_19_confirmed)
P_death
# Out:
# 0.04101355691403374

# %% [markdown]
# # ANSWER 3: Probability that a patient who has COVID will be recovered vs passing away(death)?

# %% [markdown]
# ##### Probability of Recovery is 0.29 which is higher than Probability of Dying from CoronaVirus 0.041
